# %% [markdown]
# ## **Análisis preliminar**

# %%
# Tratamiento de datos
import pandas as pd
pd.set_option('display.max_columns', None)

import sys
sys.path.append('../')

# Cargar automáticamente los archivos src
# %load_ext autoreload
# %autoreload 2

#Funciones personalizadas
from src import sp_eda as se

# %%
df = pd.read_csv("../data/cuestionario_bruto.csv")

# %%
se.analisis_preliminar(df)
# Out:
#        P1  P2 P2.1    P3                       P4  P5  \
# 163  2002  No   Sí   NaN                       28   0
# 79   1982  No   Sí   NaN             Cuánto antes   8
# 59   2001  No   Sí   NaN  A partir de los 30 años   2
# 223  1971  Sí  NaN  33.0                      NaN   0
# 221  1978  Sí  NaN  28.0                      NaN   5
#
#                                        P6  \
# 163                De nadie en particular
# 79   Entorno laboral, Sociedad en general
# 59                 De nadie en particular
# 223                De nadie en particular
# 221                De nadie en particular
#
#                                                   P7               P8.1 P8.2  \
# 163                                             N.C.                  8    8
# 79                                               NaN                  2    1
# 59                                               NaN                  8    2
# ...

# %% [markdown]
# Imprimimos los resultados que sean igual a 2020 para ver cuántas respuestas hay

# %%
print((df['P1'] == 2020).sum())

# Habrá que eliminar esas dos respuestas
# Out:
# 2
